# %%
import warnings
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns

# %%
data=pd.read_csv("bank_marketing_updated_v1.csv")
# Out:
# C:\Users\91996\AppData\Local\Temp\ipykernel_4512\21669859.py:1: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("bank_marketing_updated_v1.csv")

# %%
data.head()
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
# ...

# %%
data=pd.read_csv("bank_marketing_updated_v1.csv",skiprows=2) #for ignoring the first 2 rows

# %%
data.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
data.drop("customerid",axis=1,inplace=True)

# %%
data.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# ...

# %%
#diving jobedu into job and education columns
data["Job"]=data.jobedu.apply(lambda x:x.split(",")[0])

# %%
data.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           Job
# ...

# %%
data["Education"]=data.jobedu.apply(lambda x:x.split(",")[1])

# %%
data.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           Job  Education
# ...

# %%
#deleting the jobedu columns
data.drop("jobedu",axis=1,inplace=True)

# %%
data.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# 2  may, 2017   76 sec         1     -1         0  unknown       no
# 3  may, 2017   92 sec         1     -1         0  unknown       no
# 4  may, 2017  198 sec         1     -1         0  unknown       no
#
#             Job  Education
# 0    management   tertiary
# 1    technician  secondary
# ...

# %%
data.month.value_counts()
# Out:
# month
# may, 2017    13747
# jul, 2017     6888
# aug, 2017     6240
# jun, 2017     5335
# nov, 2017     3968
# apr, 2017     2931
# feb, 2017     2646
# jan, 2017     1402
# oct, 2017      738
# sep, 2017      576
# mar, 2017      476
# dec, 2017      214
# Name: count, dtype: int64

# %%
data[data.month.apply(lambda x:isinstance(x,float)==True)]
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 189    31.0  100000        0    single       no      no     yes   no
# 769    39.0   20000      245   married      yes      no     yes   no
# 860    33.0   55000      165   married      yes      no      no   no
# 1267   36.0   50000      114   married      yes      no     yes  yes
# 1685   34.0   20000      457   married      yes      no     yes   no
# 1899   49.0   16000      164  divorced      yes      no     yes   no
# 2433   26.0   60000     3825   married      yes      no     yes   no
# 2612   38.0   50000      446    single       no      no     yes   no
# 2747   48.0  120000     2550   married       no      no     yes   no
# 3556   41.0   20000       59   married      yes      no     yes   no
# 3890   56.0   55000     4391   married       no      no     yes   no
# 5311   22.0   20000        0    single      yes      no     yes   no
# 6265   32.0   50000       13    single      yes      no     yes   no
# ...

# %%
#checking for missing values

# %%
data.isnull().sum() #syntax for missing values
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# Job           0
# Education     0
# dtype: int64

# %%
data.shape
# Out:
# (45211, 19)

# %%
##### dropping record with missing age

# %%
data=data[~data.age.isnull()]

# %%
data
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
data.isnull().sum()
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# Job           0
# Education     0
# dtype: int64

# %%
data.month.value_counts()
# Out:
# month
# may, 2017    13740
# jul, 2017     6885
# aug, 2017     6235
# jun, 2017     5333
# nov, 2017     3967
# apr, 2017     2930
# feb, 2017     2646
# jan, 2017     1402
# oct, 2017      737
# sep, 2017      576
# mar, 2017      476
# dec, 2017      214
# Name: count, dtype: int64

# %%
data.month.mode()
# Out:
# 0    may, 2017
# Name: month, dtype: object

# %%
#imputing missing values with frequent months
freq_month=data.month.mode()[0]
freq_month
# Out:
# 'may, 2017'

# %%
data.month.fillna(freq_month,inplace=True)
# Out:
# C:\Users\91996\AppData\Local\Temp\ipykernel_4512\1180414206.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.month.fillna(freq_month,inplace=True)

# %%
data.month.value_counts(normalize=True)
# Out:
# month
# may, 2017    0.305149
# jul, 2017    0.152353
# aug, 2017    0.137970
# jun, 2017    0.118010
# nov, 2017    0.087783
# apr, 2017    0.064836
# feb, 2017    0.058551
# jan, 2017    0.031024
# oct, 2017    0.016309
# sep, 2017    0.012746
# mar, 2017    0.010533
# dec, 2017    0.004735
# Name: proportion, dtype: float64

# %%
data.isnull().sum() #syntax for missing values
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# Job           0
# Education     0
# dtype: int64

# %%
data.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# 2  may, 2017   76 sec         1     -1         0  unknown       no
# 3  may, 2017   92 sec         1     -1         0  unknown       no
# 4  may, 2017  198 sec         1     -1         0  unknown       no
#
#             Job  Education
# 0    management   tertiary
# 1    technician  secondary
# ...

# %%
data.pdays.describe()
# Out:
# count    45191.000000
# mean        40.181253
# std        100.074099
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %%
#-1 indicates missing values

# %%
#replacing it with NAN as so that -1 does not get included in calculation
data.loc[data.pdays<0,"pdays"]=np.nan

# %%
data.pdays.describe()
# Out:
# count    8252.000000
# mean      224.523752
# std       115.202715
# min         1.000000
# 25%       133.000000
# 50%       194.500000
# 75%       327.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
data.pdays.value_counts()
# Out:
# pdays
# 182.0    167
# 92.0     146
# 91.0     126
# 183.0    126
# 181.0    116
#         ...
# 541.0      1
# 543.0      1
# 871.0      1
# 550.0      1
# 530.0      1
# Name: count, Length: 557, dtype: int64

# %%
(data.response.isnull().sum()/45191)*100
# Out:
# np.float64(0.06638489964816004)

# %%
data.shape
# Out:
# (45191, 19)

# %%
data=data[~data.response.isnull()]

# %%
data
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
data.isnull().sum()
# Out:
# age              0
# salary           0
# balance          0
# marital          0
# targeted         0
# default          0
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays        36915
# previous         0
# poutcome         0
# response         0
# Job              0
# Education        0
# dtype: int64

# %%
#outliers handling

# %%
data.age.describe()
# Out:
# count    45161.000000
# mean        40.935763
# std         10.618790
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
data.age.plot.hist()
plt.show()

# %%
sns.boxplot(data.age)
plt.show()

# %%
data.balance.describe()
# Out:
# count     45161.000000
# mean       1362.850690
# std        3045.939589
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %%
plt.figure(figsize=[15,5])
sns.boxplot(data.balance)
plt.show()

# %%
data.balance.quantile([0.5,0.75,0.9,0.99])
# Out:
# 0.50      448.0
# 0.75     1428.0
# 0.90     3576.0
# 0.99    13173.4
# Name: balance, dtype: float64

# %%
data[data.balance>13173.4].describe()
# Out:
#               age         salary        balance         day    campaign  \
# count  452.000000     452.000000     452.000000  452.000000  452.000000
# mean    44.860619   68590.707965   21978.904867   16.088496    2.767699
# std     11.972457   34195.644261   11528.626384    7.996183    3.128656
# min     23.000000       0.000000   13186.000000    1.000000    1.000000
# 25%     34.000000   50000.000000   15289.750000    9.750000    1.000000
# 50%     43.000000   60000.000000   18063.500000   18.000000    2.000000
# 75%     55.000000  100000.000000   23876.500000   21.000000    3.000000
# max     84.000000  120000.000000  102127.000000   31.000000   31.000000
#
#             pdays    previous
# count   74.000000  452.000000
# mean   193.175676    0.513274
# std    113.928403    1.669420
# min     31.000000    0.000000
# 25%     97.250000    0.000000
# 50%    174.000000    0.000000
# 75%    250.750000    0.000000
# max    589.000000   23.000000

# %%
#### standardise variable
data.duration.head()
# Out:
# 0    261 sec
# 1    151 sec
# 2     76 sec
# 3     92 sec
# 4    198 sec
# Name: duration, dtype: object

# %%
data.duration.describe()
# Out:
# count       45161
# unique       2646
# top       1.5 min
# freq          138
# Name: duration, dtype: object

# %%
data.duration=data.duration.apply(lambda x: float(x.split()[0])/60 if x.find("sec")>0 else float(x.split()[0]))
# Out:
# C:\Users\91996\AppData\Local\Temp\ipykernel_4512\2981024455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.duration=data.duration.apply(lambda x: float(x.split()[0])/60 if x.find("sec")>0 else float(x.split()[0]))

# %%
data.duration.describe()
# Out:
# count    45161.000000
# mean         4.302774
# std          4.293129
# min          0.000000
# 25%          1.716667
# 50%          3.000000
# 75%          5.316667
# max         81.966667
# Name: duration, dtype: float64

# %%
data.dtypes
# Out:
# age          float64
# salary         int64
# balance        int64
# marital       object
# targeted      object
# default       object
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration     float64
# campaign       int64
# pdays        float64
# previous       int64
# poutcome      object
# response      object
# Job           object
# Education     object
# dtype: object

# %%
#univariate analysis

# %%
data.marital.value_counts()
# Out:
# marital
# married     27185
# single      12778
# divorced     5198
# Name: count, dtype: int64

# %%
data.marital.value_counts(normalize=True).plot.barh()
# Out:
# <Axes: ylabel='marital'>

# %%
data.Job.value_counts(normalize=True).plot.barh()
# Out:
# <Axes: ylabel='Job'>

# %%
data.Education.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
data.poutcome.value_counts().plot.barh()
# Out:
# <Axes: ylabel='poutcome'>

# %%
data.response.value_counts(normalize=True).plot.pie()
# Out:
# <Axes: ylabel='proportion'>

# %%
data.response.value_counts(normalize=True)
# Out:
# response
# no     0.882974
# yes    0.117026
# Name: proportion, dtype: float64

# %%
#numerical and numerical
plt.scatter(data.salary,data.balance)
plt.show()

# %%
data.plot.scatter(x="age",y="balance")
plt.show()

# %%
import seaborn as sns
sns.pairplot(data=data,vars=["salary","balance","age"])

# %%
data[["salary","balance","age"]].corr()
# Out:
#            salary   balance       age
# salary   1.000000  0.055489  0.024513
# balance  0.055489  1.000000  0.097710
# age      0.024513  0.097710  1.000000

# %%
sns.heatmap(data[["salary","balance","age"]].corr(),annot=True,cmap="Reds")
# Out:
# <Axes: >

# %%
data.groupby("response")["salary"].mean()
# Out:
# response
# no     56769.510482
# yes    58780.510880
# Name: salary, dtype: float64

# %%
data.groupby("response")["salary"].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
sns.boxplot(data=data,x="response",y="salary")
plt.show()

# %%
sns.boxplot(data=data,x="response",y="balance")
plt.show()

# %%
def percentile75(x):
    return np.quantile(x,0.8)

# %%
data.groupby("response")['balance'].aggregate(["median","mean",percentile75])
# Out:
#           median         mean  percentile75
# response
# no         417.0  1304.292281        1758.0
# yes        733.0  1804.681362        2678.0

# %%
data.groupby("response")['balance'].aggregate(["median","mean",percentile75]).plot.bar()
# Out:
# <Axes: xlabel='response'>

# %%
data.groupby("Education")['salary'].aggregate(["mean","median"]).plot.bar()
# Out:
# <Axes: xlabel='Education'>

# %%
data['response_flag']=np.where(data.response=="yes",1,0)
# Out:
# C:\Users\91996\AppData\Local\Temp\ipykernel_4512\650526236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['response_flag']=np.where(data.response=="yes",1,0)

# %%
data['response_flag'].value_counts(normalize=True)
# Out:
# response_flag
# 0    0.882974
# 1    0.117026
# Name: proportion, dtype: float64

# %%
data['response_flag'].mean()
# Out:
# np.float64(0.1170257523084077)

# %%
data.groupby("Education")["response_flag"].value_counts(normalize=True)
# Out:
# Education  response_flag
# primary    0                0.913584
#            1                0.086416
# secondary  0                0.894392
#            1                0.105608
# tertiary   0                0.849917
#            1                0.150083
# unknown    0                0.864224
#            1                0.135776
# Name: proportion, dtype: float64

# %%
data.groupby("Education")["response_flag"].mean()
# Out:
# Education
# primary      0.086416
# secondary    0.105608
# tertiary     0.150083
# unknown      0.135776
# Name: response_flag, dtype: float64

# %%
data.groupby("marital")["response_flag"].mean()
# Out:
# marital
# divorced    0.119469
# married     0.101269
# single      0.149554
# Name: response_flag, dtype: float64

# %%
data.groupby("marital")["response_flag"].mean().plot.bar()
# Out:
# <Axes: xlabel='marital'>

# %%
data.groupby("loan")["response_flag"].mean().plot.bar()
# Out:
# <Axes: xlabel='loan'>

# %%
data.groupby("housing")["response_flag"].mean().plot.bar()
# Out:
# <Axes: xlabel='housing'>

# %%
sns.boxplot(data=data,x="response",y="age")
# Out:
# <Axes: xlabel='response', ylabel='age'>

# %%
#making binning for Age

# %%
data["Age group"]=pd.cut(data.age,[0,30,40,50,60,999],labels=["<30","30-40","40-50","50-60","60+"])
# Out:
# C:\Users\91996\AppData\Local\Temp\ipykernel_4512\2321590386.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Age group"]=pd.cut(data.age,[0,30,40,50,60,999],labels=["<30","30-40","40-50","50-60","60+"])

# %%
data["Age group"].value_counts(normalize=True)
# Out:
# Age group
# 30-40    0.391090
# 40-50    0.248688
# 50-60    0.178406
# <30      0.155555
# 60+      0.026262
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=[10,4])
plt.subplot(1,2,1)
data["Age group"].value_counts(normalize=True).plot.bar()
plt.subplot(1,2,2)
data.groupby(["Age group"])["response_flag"].mean().plot.bar()
plt.show()
# Out:
# C:\Users\91996\AppData\Local\Temp\ipykernel_4512\406638437.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby(["Age group"])["response_flag"].mean().plot.bar()

# %%
data.groupby(["Job"])["response_flag"].mean().plot.bar()
plt.show()
